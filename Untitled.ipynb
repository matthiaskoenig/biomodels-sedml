# %%
import tellurium as te
from matplotlib import pyplot as plt
import pandas as pd
te.setDefaultPlottingEngine("matplotlib")
# %matplotlib inline

# %% [markdown]
# # Model loading and simulation

# %%
rr = te.loads("BIOMD0000000012_url.xml")

# %%
s = rr.simulate(start=0, end=100, steps=100)
s_df = pd.DataFrame(s, columns=s.colnames)

# %%
rr.plot(s)

# %%
#s_df

# %% [markdown]
# # Creating and running SED-ML

# %%
rr.timeCourseSelections
# Out:
# ['time', '[PX]', '[PY]', '[PZ]', '[X]', '[Y]', '[Z]']

# %%
sedml_str = """
    model1 = model "urn:miriam:biomodels.db:BIOMD0000000012"
    // Simulations
    sim1 = simulate uniform(0, 100, 1000)

    // Tasks
    task1 = run sim1 on model1

    // Outputs
    plot "Repressilator results" time vs PX, PY, PZ, X, Y, Z
    // -- End PhraSEDML block
"""

phras

# %%
te.executeSEDML(sedml_str)
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# ~/envs/biomodels-sedml/lib/python3.6/site-packages/tellurium/sedml/tesedml.py in readSEDMLDocument(cls, inputStr, workingDir)
#    1775                 from xml.etree import ElementTree
# -> 1776                 x = ElementTree.fromstring(inputStr)
#    1777                 # is parsable xml string
#
# /usr/lib/python3.6/xml/etree/ElementTree.py in XML(text, parser)
#    1313         parser = XMLParser(target=TreeBuilder())
# -> 1314     parser.feed(text)
#    1315     return parser.close()
#
# ParseError: syntax error: line 2, column 4
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-612224635979> in <module>()
# ----> 1 te.executeSEDML(sedml_str)
#
# ~/envs/biomodels-sedml/lib/python3.6/site-packages/tellurium/sedml/tesedml.py in executeSEDML(inputStr, workingDir)
#     265     """
#     266     # execute the sedml
# --> 267     factory = SEDMLCodeFactory(inputStr, workingDir=workingDir)
#     268     factory.executePython()
#     269
#
# ~/envs/biomodels-sedml/lib/python3.6/site-packages/tellurium/sedml/tesedml.py in __init__(self, inputStr, workingDir, createOutputs, saveOutputs, outputDir, plottingEngine)
#     407
#     408
# --> 409         info = SEDMLTools.readSEDMLDocument(inputStr, workingDir)
#     410         self.doc = info['doc']
#     411         self.inputType = info['inputType']
#
# ~/envs/biomodels-sedml/lib/python3.6/site-packages/tellurium/sedml/tesedml.py in readSEDMLDocument(cls, inputStr, workingDir)
#    1783             except ElementTree.ParseError:
#    1784                 if not os.path.exists(inputStr):
# -> 1785                     raise IOError("SED-ML String is not valid XML:", inputStr)
#    1786
#    1787         # SEDML-File
#
# OSError: [Errno SED-ML String is not valid XML:]
#     model1 = model "urn:miriam:biomodels.db:BIOMD0000000012"
#
#     // Simulations
#     sim1 = simulate uniform(0, 100, 1000)
#
#     // Tasks
#     task1 = run sim1 on model1
#
#     // Outputs
#     plot "Repressilator results" time vs PX, PY, PZ, X, Y, Z
#     // -- End PhraSEDML block

# %%
?? te.executeSEDML
# Out:
# Signature: te.executeSEDML(inputStr, workingDir=None)
# Source:
# def executeSEDML(inputStr, workingDir=None):
#     """ Run a SED-ML file or combine archive with results.
#
#     If a workingDir is provided the files and results are written in the workingDir.
#
#     :param inputStr:
#     :type inputStr:
#     :return:
#     :rtype:
#     """
#     # execute the sedml
#     factory = SEDMLCodeFactory(inputStr, workingDir=workingDir)
#     factory.executePython()
# File:      ~/envs/biomodels-sedml/lib/python3.6/site-packages/tellurium/sedml/tesedml.py
# Type:      function

# %%
def run_case(call_file, antimony_str, phrasedml_str, py_code=False, working_dir=None):
    """ Run one of the example phrasedml cases.

    :param case_id:
    :param antimony_str:
    :param phrasedml_str:
    :return:
    """
    # run as omex
    # FIXME: convert to combine archive
    inline_omex = '\n'.join([antimony_str, phrasedml_str])

    # output dir relative to call file
    if not working_dir:
        working_dir = os.path.join(os.path.dirname(call_file), './results')
        if not os.path.exists(working_dir):
            os.makedirs(working_dir)

    # FIXME: not working
    # write python code
    if py_code:
        fname = os.path.basename(call_file)
        py_file = os.path.join(working_dir, fname + 'code.py')
        print(py_file)
        with open(py_file, 'w') as f:
            f.write(exp._toPython(phrasedml_str, workingDir=working_dir))

    # execute python
    te.executeInlineOmex(inline_omex)
